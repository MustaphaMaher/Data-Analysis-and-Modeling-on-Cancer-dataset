# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Tumor_data.csv")

# %%
#affciher les 5 premières lignes
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#Info sur le dataset :afficher le nombre des valeurs nulles et le type de chaque colonne du dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ## Dans ce dataset on recense 569 entrées d'images chacune avec un ensemble d'attributs qui la caractèrise comme la taille,la texture,la forme etc

# %%
# Etude statistique du dataset 
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# ## Ici on observe le nombre de lignes,la moyenne ,l'ecart-type ,minimum,maximum,mediane ,etc de chaque attribut

# %%
## Recherche de valeures uniques 
print("Les valeurs uniques pour chaque colomnes")
data.nunique()
# Out:
# Les valeurs uniques pour chaque colomnes
# id                         569
# diagnosis                    2
# radius_mean                456
# texture_mean               479
# perimeter_mean             522
# area_mean                  539
# smoothness_mean            474
# compactness_mean           537
# concavity_mean             537
# concave points_mean        542
# symmetry_mean              432
# fractal_dimension_mean     499
# radius_se                  540
# texture_se                 519
# perimeter_se               533
# area_se                    528
# smoothness_se              547
# compactness_se             541
# concavity_se               533
# concave points_se          507
# symmetry_se                498
# fractal_dimension_se       545
# radius_worst               457
# texture_worst              511
# perimeter_worst            514
# area_worst                 544
# smoothness_worst           411
# compactness_worst          529
# concavity_worst            539
# ...

# %%
##Recherche de valeurs nulles 
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
## Seule la colomne Unammed: 32 prèsente des valeurs nulles sur toutes les lignes : on peut l'enlever alors
data.drop("Unnamed: 32",axis=1,inplace=True)

# %%
#Etude sur les données catégorielles : ici dans notre cas diagnosis 
count=data["diagnosis"].value_counts()
count
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## la colomne diagnosis prend 2 valeurs B(Benign) qui se répéte 357 fois et M(Malignant) 212 fois

# %%
# Etude de la distribution des valeurs de diagnosis 
plt.pie(count,labels=count.index,autopct='%1.1f%%')
plt.title("Pourcentage de la répartition des données du dataset selon diagnosis")
plt.show()

# %%
#on va transformer M en Maligne et B en Benigne 
dict_diagnosis = {
    'M': 'Malignant',
    'B': 'Benign'
}
data["diagnosis"]=data["diagnosis"].map(dict_diagnosis)

# %% [markdown]
# ## Visualisation de la distribution des autres attributs de type float

# %%
columns=data.columns
features=columns.drop(["id","diagnosis"])

# %%
features
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
for feature in features:
    plt.figure(figsize=(8,5))
    sns.histplot(data,x=feature,hue="diagnosis",kde=True)
    plt.xlabel(feature)
    plt.ylabel("count")
    plt.show()

# %% [markdown]
# ## on remarque que certaines distributions ressemblent à celle normale comme "mean smooothness","mean texture","mean symetry" alors que d'autres
# ## présentent décalées à droite indiquent plus de valeurs supérieures à la moyenne qu'inférieures comme "compactness mean" ,"concavity mean" etc

# %%
# matrice de correlation 
correlation_matrix = data.corr()
plt.figure(figsize=(18, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %% [markdown]
# ## On remarque une grande correlation entre les valeurs mean,se(standard error) et worst de compactness,texture,area,etc (possibilité d'étudier la variance cumulative)

# %%
#Analyse des relations entre les différents attributs
##Vu que mean,worst et se sont correlés et pour ne pas surcharger notre machine nous travaillerons avec les attributs mean pour voir les relations entre eux

# %%
columns_mean=('diagnosis', 'radius_mean','texture_mean', 'perimeter_mean','area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean')
df_mean = pd.DataFrame(data,columns = columns_mean)
sns.pairplot(df_mean, hue = "diagnosis", diag_kind='kde')

# %% [markdown]
# ## D'après ce graphe on peut vraiment faire la différence entre les données des cellules bénignes et malignes selon les différentes combinaisons

# %%
#Analyse de valeurs aberrantes 
## On utilise des boites à moustache

# %%
columns_set_1 = ['diagnosis' , 'radius_mean', 'radius_se', 'radius_worst']
df_set_1 = pd.DataFrame(data, columns=columns_set_1)
#df_set_radius
columns_set_2 = ['diagnosis' , 'perimeter_mean', 'perimeter_se', 'perimeter_worst']
df_set_2 = pd.DataFrame(data, columns=columns_set_2)
#df_set_perimeter
columns_set_3 = ['diagnosis' , 'area_mean', 'area_se', 'area_worst']
df_set_3 = pd.DataFrame(data, columns=columns_set_3)
#df_set_area
columns_set_4 = ['diagnosis' , 'texture_mean', 'texture_se', 'texture_worst']
df_set_4 = pd.DataFrame(data, columns=columns_set_4)
#df_set_texture
fig, axs = plt.subplots(4 , 1, figsize= (12,9)) 
#Radius
sns.boxplot(x= "variable" ,y = "value", hue= "diagnosis", data=pd.melt(df_set_1, id_vars='diagnosis'), ax = axs[0])
#Perimeter
sns.boxplot(x= "variable" ,y = "value", hue= "diagnosis", data=pd.melt(df_set_2, id_vars='diagnosis'), ax = axs[1])
#Area
sns.boxplot(x= "variable" ,y = "value", hue= "diagnosis", data=pd.melt(df_set_3, id_vars='diagnosis'),ax = axs[2])
#Texture
sns.boxplot(x= "variable" ,y = "value", hue= "diagnosis", data=pd.melt(df_set_4, id_vars='diagnosis'))
# Out:
# <AxesSubplot:xlabel='variable', ylabel='value'>

# %% [markdown]
# ## On remarque des valeurs aberrantes dans plusieurs attributs qui doivent être traités si nous souhaitons faire du machine learning avec

# %% [markdown]
# ## Etape Optionnelle de machine learning

# %%
##transformation des valeurs categorielles de diagnosis pour le traitement avec machine learning
from sklearn.preprocessing import LabelEncoder
labelEncoder=LabelEncoder()
data["diagnosis"]=labelEncoder.fit_transform(data["diagnosis"])
data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
from sklearn.model_selection import train_test_split
x=data.drop("diagnosis",axis=1)
y=data[["diagnosis"]]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2,test_size=0.2)

# %%
#Normalisation des données pour une meilleure précision du modèle
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
x_train = sc_X.fit_transform(x_train)
x_test = sc_X.transform(x_test)

# %%
##SVC 
from sklearn.svm import SVC
classifier=SVC(kernel='rbf')
classifier.fit(x_train,y_train)
classifier.score(x_test,y_test)
# Out:
# C:\Users\zouari\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9736842105263158

# %%
## Régression Logistqiue
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# C:\Users\zouari\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(random_state=0)

# %%
y_Pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_Pred)
show = pd.DataFrame(cm,columns=["true","false"],index=["true","false"])
show.head()
# Out:
#        true  false
# true     66      3
# false     1     44

# %%
from sklearn.metrics import accuracy_score
print("Accuracy=", accuracy_score(y_test, y_Pred))
# Out:
# Accuracy= 0.9649122807017544
